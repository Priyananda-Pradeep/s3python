# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyananda-Pradeep/s3python/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Ask the user to enter two numbers and display their sum

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Sum =", num1 + num2)
# Out:
# Enter first number: 1
# Enter second number: 2
# Sum = 3.0

# %%
# 2. Ask the user to enter two numbers and display their product

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Product =", num1 * num2)
# Out:
# Enter first number: 1
# Enter second number: 2
# Product = 2.0

# %%
# 3. Calculate the area of a rectangle

length = float(input("Enter length: "))
width = float(input("Enter width: "))

area = length * width

print("Area of Rectangle =", area)
# Out:
# Enter length: 1
# Enter width: 3
# Area of Rectangle = 3.0

# %%
# 4. Calculate the area of a circle

radius = float(input("Enter radius: "))

area = 3.14159 * radius * radius

print("Area of Circle =", area)
# Out:
# Enter radius: 1
# Area of Circle = 3.14159

# %%
# 5. calulate and display total mark
sub1 = float(input("Enter marks of first subject: "))
sub2 = float(input("Enter marks of second subject: "))
sub3 = float(input("Enter marks of third subject: "))
sub4 = float(input("Enter marks of fourth subject: "))
sub5 = float(input("Enter marks of fifth subject: "))

total = sub1 + sub2 + sub3 + sub4 + sub5

print("Total Marks =", total)
# Out:
# Enter marks of first subject: 1
# Enter marks of second subject: 2
# Enter marks of third subject: 3
# Enter marks of fourth subject: 4
# Enter marks of fifth subject: 5
# Total Marks = 6.0

# %%
# 6. Function to display "Hello CBS"

def hello():
    print("Hello CBS")

hello()
# Out:
# Hello CBS

# %%
# 7. Function to display your name

def my_name():
    print("Priya")   # Replace with your name if needed

my_name()
# Out:
# Priya

# %%
# 8. Function to display the square of 10

def square():
    print(10 ** 2)

square()
# Out:
# 100

# %%
# 9. Function to display the sum of 20 and 30

def add():
    print(20 + 30)

add()
# Out:
# 50
